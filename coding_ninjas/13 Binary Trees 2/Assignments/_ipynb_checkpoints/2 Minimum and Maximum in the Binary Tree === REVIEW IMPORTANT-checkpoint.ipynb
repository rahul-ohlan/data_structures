# %%
import queue
class binarytree:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
        
class Pair:
    def __init__(self,minimum,maximum):
        self.minimum = minimum
        self.maximum = maximum
        
def takelevelwiseinput():
    que = queue.Queue()
    print('enter root data: ')
    rootdata = int(input())
    if rootdata == -1:
        return None
    root = binarytree(rootdata)
    que.put(root)
    while not que.empty():
        currentnode = que.get()
        print('enter left child of:',currentnode.data)
        leftchilddata = int(input())
        if leftchilddata!=-1:
            leftchild = binarytree(leftchilddata)
            currentnode.left = leftchild
            que.put(leftchild)
        print('enter right child of:',currentnode.data)
        rightchilddata = int(input())
        if rightchilddata!=-1:
            rightchild = binarytree(rightchilddata)
            currentnode.right = rightchild
            que.put(rightchild)
    return root

def printlevelwise(root):
    que = queue.Queue()
    if root is None:
        return
    que.put(root)
    while not que.empty():
        currentnode = que.get()
        print(currentnode.data,end=':')
        if currentnode.left!=None:
            print('L:',currentnode.left.data,end=',')
            que.put(currentnode.left)
        else:
            print('L:',-1,end=',')
        if currentnode.right!=None:
            print('R:',currentnode.right.data)
            que.put(currentnode.right)
        else:
            print('R:',-1)
    return        

def createDuplicateNode(root):
    if root == None:
        return None
    temp = binarytree(root.data)
    temp.left = root.left
    root.left = temp
    createDuplicateNode(temp.left)
    createDuplicateNode(root.right)
    return

def findminmax(root):
    if root.left!=None:
        Leftpair = findminmax(root.left)
    else:
        Leftpair = Pair(root.data,root.data)
    if root.right!=None:
        Rightpair = findminmax(root.right)
    else:
        Rightpair = Pair(root.data,root.data)
    Global = Pair(min(Leftpair.minimum,Rightpair.minimum,root.data),max(Leftpair.maximum,Rightpair.maximum,root.data))
    
    return Global

# %%
rahul = takelevelwiseinput()
res = findminmax(rahul)
print(res.minimum,res.maximum)
# Out:
# enter root data:
# 10
# enter left child of: 10
# 20
# enter right child of: 10
# 5
# enter left child of: 20
# -1
# enter right child of: 20
# -1
# enter left child of: 5
# -1
# enter right child of: 5
# -1
# 5 20
